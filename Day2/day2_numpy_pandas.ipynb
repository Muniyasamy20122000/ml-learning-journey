# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import sklearn

# %%
print("Setup complete")
# Out:
# Setup complete

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Numpy basics
a = np.array([10,20,30,40,50])
print("Array a:", a)
print("Multiply by 2:", a*2)

#Pandas basics
data = {'Name': ['Tom', 'Jerry', 'Mickey'], 'Marks': [90, 85, 92]}
df = pd.DataFrame(data)
print(df)

#Matplotlib simple plot
x = [1,2,3,4]
y = [10,20,25,30]
plt.plot(x,y)
plt.title("Simple Line Plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
# Out:
# Array a: [10 20 30 40 50]
# Multiply by 2: [ 20  40  60  80 100]
#      Name  Marks
# 0     Tom     90
# 1   Jerry     85
# 2  Mickey     92
